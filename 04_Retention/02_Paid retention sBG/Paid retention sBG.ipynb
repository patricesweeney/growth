# %% [markdown]
# # Paid retention sBG (Shifted Beta-Geometric)

# %% [markdown]
# ## Fake data

# %%
import pandas as pd
import numpy as np
from faker import Faker

def create_data(num_customers=1000):
    fake = Faker()
    np.random.seed(42)
    
    customer_data = []
    
    for _ in range(num_customers):
        customer_id = fake.uuid4()
        start_date = fake.date_between(start_date='-4y', end_date='today')
        paid_conversion_date = fake.date_between(start_date=start_date, end_date='today')
        churn_date = fake.date_between(start_date=paid_conversion_date, end_date='today') if np.random.rand() > 0.5 else None
        
        dim_1 = fake.random_int(min=1, max=5)
        dim_2 = fake.random_element(elements=('A', 'B', 'C', 'D', 'E'))
        dim_3 = fake.random_number(digits=2)
        
        customer_data.append([
            customer_id,
            paid_conversion_date,
            churn_date,
            dim_1,
            dim_2,
            dim_3
        ])
    
    columns = ['customer_id', 'paid_conversion_date', 'churn_date', 'dim_1', 'dim_2', 'dim_3']
    return pd.DataFrame(customer_data, columns=columns)

# Generate the data
data = create_data()
data
# Out:
#                               customer_id paid_conversion_date  churn_date  \
# 0    51114ad3-b445-4ac7-a58c-179d9d96dedd           2021-08-17        None
# 1    1e798f6b-115f-4aba-b888-7bb313bfc579           2024-01-12  2024-02-17
# 2    c0e9712b-3e55-4e5e-afe0-be74792d3503           2024-02-03  2024-05-07
# 3    e58c8e0b-e84a-47d3-bdda-4fbb16e64b34           2024-05-17  2024-06-08
# 4    5a23b1be-65fc-4bb7-9b78-66cf70c93f3a           2024-05-05        None
# ..                                    ...                  ...         ...
# 995  9ce5e8ce-2550-45bb-bce0-deb1dfe6e8f5           2024-06-24        None
# 996  59de8361-ae72-4a69-a884-594f9a113b7c           2024-04-18  2024-05-24
# 997  8e31f4d9-d257-488c-8f76-17d3920872b9           2022-10-29        None
# 998  25d45bf4-c99e-48a7-a67f-e5cb61184650           2024-04-09  2024-05-12
# 999  f0cc18f9-d290-4353-92cd-7006203e82c5           2023-04-08        None
#
#      dim_1 dim_2  dim_3
# 0        3     C     98
# 1        5     D     60
# 2        1     A     46
# 3        3     D     94
# 4        4     B     33
# ..     ...   ...    ...
# 995      3     D     79
# 996      2     D     11
# 997      1     E     72
# 998      4     D     92
# 999      5     A     65
#
# [1000 rows x 6 columns]

# %% [markdown]
# ## Data preprocessing

# %%
import pandas as pd
import numpy as np
import torch
import pyro
import pyro.distributions as dist
from pyro.infer import MCMC, NUTS
import matplotlib.pyplot as plt

def preprocess_data(data):
    data['paid_conversion_date'] = pd.to_datetime(data['paid_conversion_date'])
    data['churn_date'] = pd.to_datetime(data['churn_date'], errors='coerce')

    # Assume period is in months
    data['period'] = ((data['churn_date'].fillna(pd.Timestamp('today')) - data['paid_conversion_date']).dt.days // 30).astype(int)

    # Number of customers at each period
    period_max = data['period'].max()
    customers_remaining = [(data['period'] >= t).sum() for t in range(period_max + 1)]
    churned = [customers_remaining[t] - customers_remaining[t+1] if t < period_max else customers_remaining[t] for t in range(period_max + 1)]
    
    churn_data = pd.DataFrame({
        'period': range(period_max + 1),
        'customers_remaining': customers_remaining,
        'churned': churned
    })
    
    data_dict = {
        "customers_remaining": torch.tensor(customers_remaining, dtype=torch.float),
        "churned": torch.tensor(churned, dtype=torch.float)
    }
    
    return churn_data, data_dict

churn_data, data_dict = preprocess_data(data)

# Display the first few rows of the churn_data DataFrame
churn_data
# Out:
#     period  customers_remaining  churned
# 0        0                 1000      180
# 1        1                  820      110
# 2        2                  710       75
# 3        3                  635       54
# 4        4                  581       50
# 5        5                  531       37
# 6        6                  494       42
# 7        7                  452       30
# 8        8                  422       28
# 9        9                  394       29
# 10      10                  365       30
# 11      11                  335       33
# 12      12                  302       40
# 13      13                  262       26
# 14      14                  236       27
# 15      15                  209       21
# 16      16                  188       16
# 17      17                  172       14
# 18      18                  158       16
# 19      19                  142       16
# 20      20                  126       14
# 21      21                  112       13
# 22      22                   99        6
# 23      23                   93       10
# 24      24                   83        7
# 25      25                   76        2
# 26      26                   74        5
# 27      27                   69       10
# 28      28                   59        7
# 29      29                   52        4
# 30      30                   48        5
# 31      31                   43        4
# 32      32                   39        7
# 33      33                   32        0
# 34      34                   32        7
# 35      35                   25        4
# 36      36                   21        5
# 37      37                   16        6
# 38      38                   10        2
# 39      39                    8        4
# 40      40                    4        2
# 41      41                    2        2

# %% [markdown]
# ## sBG model

# %% [markdown]
# - Customers renew or cancel their contracts based on a fixed probability (coin flip model).
# - This probability varies across customers and follows a beta distribution.
# - The model assumes customer behavior remains consistent over time.

# %%
def sBG_model(data_dict):
    customers_remaining = data_dict["customers_remaining"]
    churned = data_dict["churned"]
    
    # Priors for alpha and beta
    alpha = pyro.sample('alpha', dist.Gamma(1.0, 1.0))
    beta = pyro.sample('beta', dist.Gamma(1.0, 1.0))

    # Survivor function S(t) for periods 0 to n_periods
    S = [torch.tensor(1.0)] + [torch.exp(dist.Beta(alpha, beta + t).log_prob(torch.tensor(0.0))) for t in range(1, len(customers_remaining))]
    
    # Churn probability for each period
    P = torch.tensor([S[t-1] - S[t] for t in range(1, len(customers_remaining))], dtype=torch.float)

    # Observation of churned customers
    with pyro.plate('data', len(churned)):
        pyro.sample('obs', dist.Binomial(total_count=customers_remaining[:-1], probs=P), obs=churned)

# Inference using NUTS
nuts_kernel = NUTS(sBG_model)
mcmc = MCMC(nuts_kernel, num_samples=2000, warmup_steps=500)
mcmc.run(data_dict)

# Extract samples
posterior_samples = mcmc.get_samples()
alpha_post = posterior_samples['alpha']
beta_post = posterior_samples['beta']

# Plot posterior distributions
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.hist(alpha_post.numpy(), bins=50, alpha=0.7, label='alpha')
plt.legend()

plt.subplot(1, 2, 2)
plt.hist(beta_post.numpy(), bins=50, alpha=0.7, label='beta')
plt.legend()
plt.show()

# Summarize the posterior distributions
print("Posterior summary:")
print(f"Alpha: Mean={alpha_post.mean():.2f}, Std={alpha_post.std():.2f}")
print(f"Beta: Mean={beta_post.mean():.2f}, Std={beta_post.std():.2f}")
# Out:
# Warmup:   0%|          | 0/2500 [00:00, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/envs/ds/lib/python3.11/site-packages/pyro/poutine/trace_messenger.py:191, in TraceHandler.__call__(self, *args, **kwargs)
#     190 try:
# --> 191     ret = self.fn(*args, **kwargs)
#     192 except (ValueError, RuntimeError) as e:
#
# Cell In[15], line 17, in sBG_model(data_dict)
#      16 with pyro.plate('data', len(churned)):
# ---> 17     pyro.sample('obs', dist.Binomial(total_count=customers_remaining[:-1], probs=P), obs=churned)
#
# File /opt/anaconda3/envs/ds/lib/python3.11/site-packages/pyro/primitives.py:189, in sample(name, fn, obs, obs_mask, infer, *args, **kwargs)
#     188 # apply the stack and return its return value
# --> 189 apply_stack(msg)
#     190 assert msg["value"] is not None  # type narrowing guaranteed by apply_stack
#
# File /opt/anaconda3/envs/ds/lib/python3.11/site-packages/pyro/poutine/runtime.py:378, in apply_stack(initial_msg)
#     376 pointer = pointer + 1
# --> 378 frame._process_message(msg)
#     380 if msg["stop"]:
#
# File /opt/anaconda3/envs/ds/lib/python3.11/site-packages/pyro/poutine/plate_messenger.py:25, in PlateMessenger._process_message(self, msg)
#      24 super()._process_message(msg)
# ---> 25 BroadcastMessenger._pyro_sample(msg)
#
# File /opt/anaconda3/envs/ds/lib/python3.11/contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      80 with self._recreate_cm():
# ---> 81     return func(*args, **kwds)
#
# File /opt/anaconda3/envs/ds/lib/python3.11/site-packages/pyro/poutine/broadcast_messenger.py:74, in BroadcastMessenger._pyro_sample(msg)
#      70 if (
#      71     target_batch_shape[f.dim] is not None
#      72     and target_batch_shape[f.dim] != f.size
#      73 ):
# ---> 74     raise ValueError(
#      75         "Shape mismatch inside plate('{}') at site {} dim {}, {} vs {}".format(
#      76             f.name,
#      77             msg["name"],
#      78             f.dim,
#      79             f.size,
#      80             target_batch_shape[f.dim],
#      81         )
#      82     )
#      83 target_batch_shape[f.dim] = f.size
#
# ValueError: Shape mismatch inside plate('data') at site obs dim -1, 36 vs 35
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 22
#      20 nuts_kernel = NUTS(sBG_model)
#      21 mcmc = MCMC(nuts_kernel, num_samples=2000, warmup_steps=500)
# ---> 22 mcmc.run(data_dict)
#      24 # Extract samples
#      25 posterior_samples = mcmc.get_samples()
#
# File /opt/anaconda3/envs/ds/lib/python3.11/site-packages/pyro/poutine/messenger.py:32, in _context_wrap(context, fn, *args, **kwargs)
#      25 def _context_wrap(
#      26     context: "Messenger",
#      27     fn: Callable,
#      28     *args: Any,
#      29     **kwargs: Any,
#      30 ) -> Any:
#      31     with context:
# ---> 32         return fn(*args, **kwargs)
#
# File /opt/anaconda3/envs/ds/lib/python3.11/site-packages/pyro/infer/mcmc/api.py:565, in MCMC.run(self, *args, **kwargs)
#     556 with optional(
#     557     pyro.validation_enabled(not self.disable_validation),
#     558     self.disable_validation is not None,
#    (...)
#     562     # This also resolves "RuntimeError: Cowardly refusing to serialize non-leaf tensor which
#     563     # requires_grad", which happens with `jit_compile` under PyTorch 1.7
#     564     args = [arg.detach() if torch.is_tensor(arg) else arg for arg in args]
# --> 565     for x, chain_id in self.sampler.run(*args, **kwargs):
#     566         if num_samples[chain_id] == 0:
#     567             num_samples[chain_id] += 1
#
# File /opt/anaconda3/envs/ds/lib/python3.11/site-packages/pyro/infer/mcmc/api.py:225, in _UnarySampler.run(self, *args, **kwargs)
#     223 logger = initialize_logger(logger, "", progress_bar)
#     224 hook_w_logging = _add_logging_hook(logger, progress_bar, self.hook)
# --> 225 for sample in _gen_samples(
#     226     self.kernel,
#     227     self.warmup_steps,
#     228     self.num_samples,
#     229     hook_w_logging,
#     230     i if self.num_chains > 1 else None,
#     231     *args,
#     232     **kwargs
#     233 ):
#     234     yield sample, i  # sample, chain_id
#     235 self.kernel.cleanup()
#
# File /opt/anaconda3/envs/ds/lib/python3.11/site-packages/pyro/infer/mcmc/api.py:146, in _gen_samples(kernel, warmup_steps, num_samples, hook, chain_id, *args, **kwargs)
#     145 def _gen_samples(kernel, warmup_steps, num_samples, hook, chain_id, *args, **kwargs):
# --> 146     kernel.setup(warmup_steps, *args, **kwargs)
#     147     params = kernel.initial_params
#     148     save_params = getattr(kernel, "save_params", sorted(params))
#
# File /opt/anaconda3/envs/ds/lib/python3.11/site-packages/pyro/infer/mcmc/hmc.py:345, in HMC.setup(self, warmup_steps, *args, **kwargs)
#     343 self._warmup_steps = warmup_steps
#     344 if self.model is not None:
# --> 345     self._initialize_model_properties(args, kwargs)
#     346 if self.initial_params:
#     347     z = {k: v.detach() for k, v in self.initial_params.items()}
#
# File /opt/anaconda3/envs/ds/lib/python3.11/site-packages/pyro/infer/mcmc/hmc.py:279, in HMC._initialize_model_properties(self, model_args, model_kwargs)
#     278 def _initialize_model_properties(self, model_args, model_kwargs):
# --> 279     init_params, potential_fn, transforms, trace = initialize_model(
#     280         self.model,
#     281         model_args,
#     282         model_kwargs,
#     283         transforms=self.transforms,
#     284         max_plate_nesting=self._max_plate_nesting,
#     285         jit_compile=self._jit_compile,
#     286         jit_options=self._jit_options,
#     287         skip_jit_warnings=self._ignore_jit_warnings,
#     288         init_strategy=self._init_strategy,
#     289         initial_params=self._initial_params,
#     290     )
#     291     self.potential_fn = potential_fn
#     292     self.transforms = transforms
#
# File /opt/anaconda3/envs/ds/lib/python3.11/site-packages/pyro/infer/mcmc/util.py:427, in initialize_model(model, model_args, model_kwargs, transforms, max_plate_nesting, jit_compile, jit_options, skip_jit_warnings, num_chains, init_strategy, initial_params)
#     425     automatic_transform_enabled = False
#     426 if max_plate_nesting is None:
# --> 427     max_plate_nesting = _guess_max_plate_nesting(model, model_args, model_kwargs)
#     428 # Wrap model in `poutine.enum` to enumerate over discrete latent sites.
#     429 # No-op if model does not have any discrete latents.
#     430 model = poutine.enum(
#     431     config_enumerate(model), first_available_dim=-1 - max_plate_nesting
#     432 )
#
# File /opt/anaconda3/envs/ds/lib/python3.11/site-packages/pyro/infer/mcmc/util.py:251, in _guess_max_plate_nesting(model, args, kwargs)
#     245 """
#     246 Guesses max_plate_nesting by running the model once
#     247 without enumeration. This optimistically assumes static model
#     248 structure.
#     249 """
#     250 with poutine.block():
# --> 251     model_trace = poutine.trace(model).get_trace(*args, **kwargs)
#     252 sites = [site for site in model_trace.nodes.values() if site["type"] == "sample"]
#     254 dims = [
#     255     frame.dim
#     256     for site in sites
#     257     for frame in site["cond_indep_stack"]
#     258     if frame.vectorized
#     259 ]
#
# File /opt/anaconda3/envs/ds/lib/python3.11/site-packages/pyro/poutine/trace_messenger.py:216, in TraceHandler.get_trace(self, *args, **kwargs)
#     208 def get_trace(self, *args, **kwargs) -> Trace:
#     209     """
#     210     :returns: data structure
#     211     :rtype: pyro.poutine.Trace
#    (...)
#     214     Calls this poutine and returns its trace instead of the function's return value.
#     215     """
# --> 216     self(*args, **kwargs)
#     217     return self.msngr.get_trace()
#
# File /opt/anaconda3/envs/ds/lib/python3.11/site-packages/pyro/poutine/trace_messenger.py:198, in TraceHandler.__call__(self, *args, **kwargs)
#     196         exc = exc_type("{}\n{}".format(exc_value, shapes))
#     197         exc = exc.with_traceback(traceback)
# --> 198         raise exc from e
#     199     self.msngr.trace.add_node(
#     200         "_RETURN", name="_RETURN", type="return", value=ret
#     201     )
#     202 return ret
#
# File /opt/anaconda3/envs/ds/lib/python3.11/site-packages/pyro/poutine/trace_messenger.py:191, in TraceHandler.__call__(self, *args, **kwargs)
#     187 self.msngr.trace.add_node(
#     188     "_INPUT", name="_INPUT", type="args", args=args, kwargs=kwargs
#     189 )
#     190 try:
# --> 191     ret = self.fn(*args, **kwargs)
#     192 except (ValueError, RuntimeError) as e:
#     193     exc_type, exc_value, traceback = sys.exc_info()
#
# Cell In[15], line 17, in sBG_model(data_dict)
#      15 # Observation of churned customers
#      16 with pyro.plate('data', len(churned)):
# ---> 17     pyro.sample('obs', dist.Binomial(total_count=customers_remaining[:-1], probs=P), obs=churned)
#
# File /opt/anaconda3/envs/ds/lib/python3.11/site-packages/pyro/primitives.py:189, in sample(name, fn, obs, obs_mask, infer, *args, **kwargs)
#     172 msg = Message(
#     173     type="sample",
#     174     name=name,
#    (...)
#     186     continuation=None,
#     187 )
#     188 # apply the stack and return its return value
# --> 189 apply_stack(msg)
#     190 assert msg["value"] is not None  # type narrowing guaranteed by apply_stack
#     191 return msg["value"]
#
# File /opt/anaconda3/envs/ds/lib/python3.11/site-packages/pyro/poutine/runtime.py:378, in apply_stack(initial_msg)
#     375 for frame in reversed(stack):
#     376     pointer = pointer + 1
# --> 378     frame._process_message(msg)
#     380     if msg["stop"]:
#     381         break
#
# File /opt/anaconda3/envs/ds/lib/python3.11/site-packages/pyro/poutine/plate_messenger.py:25, in PlateMessenger._process_message(self, msg)
#      23 def _process_message(self, msg: "Message") -> None:
#      24     super()._process_message(msg)
# ---> 25     BroadcastMessenger._pyro_sample(msg)
#
# File /opt/anaconda3/envs/ds/lib/python3.11/contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# File /opt/anaconda3/envs/ds/lib/python3.11/site-packages/pyro/poutine/broadcast_messenger.py:74, in BroadcastMessenger._pyro_sample(msg)
#      69     target_batch_shape = prefix_batch_shape + target_batch_shape
#      70     if (
#      71         target_batch_shape[f.dim] is not None
#      72         and target_batch_shape[f.dim] != f.size
#      73     ):
# ---> 74         raise ValueError(
#      75             "Shape mismatch inside plate('{}') at site {} dim {}, {} vs {}".format(
#      76                 f.name,
#      77                 msg["name"],
#      78                 f.dim,
#      79                 f.size,
#      80                 target_batch_shape[f.dim],
#      81             )
#      82         )
#      83     target_batch_shape[f.dim] = f.size
#      84 # Starting from the right, if expected size is None at an index,
#      85 # set it to the actual size if it exists, else 1.
#
# ValueError: Shape mismatch inside plate('data') at site obs dim -1, 36 vs 35
# Trace Shapes:
#  Param Sites:
# Sample Sites:
#    alpha dist    |
#         value    |
#     beta dist    |
#         value    |
#     data dist    |
#         value 36 |
